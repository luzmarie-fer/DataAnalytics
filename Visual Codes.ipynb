# %% [markdown]
# <a href="https://colab.research.google.com/github/luzmarie-fer/DataAnalytics/blob/main/Visual%20Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Deaths%20in%20Eastern%20Asia.csv'
df = pd.read_csv(url)
df
# Out:
#   Country  Deaths
# 0  Taiwan     212
# 1   Japan   20034
# 2   Korea       0
# 3   China   92165

# %%
labels= ['Taiwan', 'Japan', 'Korea', 'China']
colors=['#ED553B', '#20639b', '#3CAEA3', '#d45087']

sizes= [8, 235, 113, 235]
plt.figure(figsize = (23,10))
plt.pie(sizes,labels=labels, colors=colors, startangle=90, shadow=True,explode=(0, 0, 0, 0), autopct='%1.2f%%')

plt.axis('equal')
plt.title('Earthquake Deaths Incidents\n', fontdict={'fontname': 'Serif','fontweight':'bold', 'fontsize':20})
plt.legend(labels,loc=1)
plt.show()

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Deaths%20in%20Eastern%20Asia.csv'
df = pd.read_csv(url)
df
# Out:
#   Country  Deaths
# 0  Taiwan     212
# 1   Japan   20034
# 2   Korea       0
# 3   China   92165

# %%
plt.figure(figsize = (17,10))
plt.title("\n Total Deaths in 2 Decades", fontweight="bold", fontsize=20)
plt.bar(x=df['Country'],
 
        height=df['Deaths'],
 
        color='#003f5c')
 
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Damage%20Chart%20by%20Year.csv'
df = pd.read_csv(url)
df
# Out:
#     Year  TotalDamagesAdjusted
# 0   2002                 37661
# 1   2003                829296
# 2   2004              40346342
# 3   2005                555005
# 4   2006                  9666
# 5   2007              17109549
# 6   2008             321898938
# 7   2009                906992
# 8   2010               1869464
# 9   2011             253390703
# 10  2012               1826969
# 11  2013               9372160
# 12  2014               6457866
# 13  2015                 37556
# 14  2016              23733410
# 15  2017                589209
# 16  2018               5049117
# 17  2019               1379982
# 18  2020                 17799
# 19  2021               9212000
# 20  2022                     0

# %%
#visualization
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)

#Plot
sns.set_theme(style="ticks", color_codes=False)
ax = sns.barplot(x="Year", y="TotalDamagesAdjusted", ci="sd",data=df)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)

#labels
plt.xlabel("Year", fontweight = "bold", fontsize = 20)
plt.ylabel("TotalDamagesAdjusted", fontweight = "bold", fontsize = 20)
plt.title("Total Damages in over 2 Decades", fontweight = "bold", fontsize = 20)

plt.show()

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/consumer%20price%20index.csv'
df = pd.read_csv(url)
df
# Out:
#     Year         CPI
# 0   2002   66.381964
# 1   2003   67.888896
# 2   2004   69.706442
# 3   2005   72.071410
# 4   2006   74.396387
# 5   2007   76.518679
# 6   2008   79.456304
# 7   2009   79.173803
# 8   2010   80.472285
# 9   2011   83.012674
# 10  2012   84.730479
# 11  2013   85.971642
# 12  2014   87.366298
# 13  2015   87.469932
# 14  2016   88.573453
# 15  2017   90.460179
# 16  2018   92.669670
# 17  2019   94.349092
# 18  2020   95.512967
# 19  2021  100.000000

# %%
#visualization
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)

#assigninng value of x and y
x = df['Year']
y = df['CPI']

#Plot
(markers, stemlines, baseline) = plt.stem(x,y, use_line_collection=True)
plt.setp(stemlines,linestyle="-", color="green", linewidth=0.5 )
plt.setp(markers, marker='D', markersize=10, markeredgecolor="orange", markeredgewidth=2)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)


#labels
plt.xlabel("Year", fontweight = "bold", fontsize = 15)
plt.ylabel("CPI", fontweight = "bold", fontsize = 15)
plt.title("Consumer Price Index (2002-2020)", fontweight = "bold", fontsize = 20)


plt.show()

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/C.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#      Year Dis Mag Scale  No Injured  No Affected  No Homeless  Total Deaths  \
# 0    2002       Richter         NaN        330.0         48.0           NaN
# 1    2002       Richter         NaN      65500.0          NaN           2.0
# 2    2002       Richter       200.0        300.0          NaN           4.0
# 3    2003       Richter       143.0       2160.0          NaN           NaN
# 4    2003       Richter       773.0          NaN          NaN           2.0
# ..    ...           ...         ...          ...          ...           ...
# 125  2019       Richter        28.0        432.0          NaN           NaN
# 126  2021       Richter       185.0       7647.0         60.0           1.0
# 127  2021       Richter        11.0        600.0          NaN           NaN
# 128  2022       Richter        41.0      13500.0          NaN           4.0
# 129  2022       Richter       183.0        558.0          NaN           3.0
#
#      Total Affected         CPI
# ...

# %%
df.describe()
# Out:
#               Year     No Injured   No Affected    No Homeless  Total Deaths  \
# count   130.000000     110.000000  9.800000e+01      48.000000     74.000000
# mean   2011.307692    4318.536364  6.088020e+05   28239.437500   1519.067568
# std       5.746379   35087.910301  4.603244e+06   62784.027274  10392.738681
# min    2002.000000       1.000000  1.250000e+02       6.000000      1.000000
# 25%    2006.000000      19.000000  5.525000e+03     474.000000      2.000000
# 50%    2011.500000      64.000000  2.263500e+04    3599.500000      4.000000
# 75%    2016.000000     391.250000  1.380000e+05   27863.750000     22.750000
# max    2022.000000  366596.000000  4.561000e+07  350000.000000  87476.000000
#
#        Total Affected         CPI
# count    1.290000e+02  126.000000
# mean     4.766909e+05   82.066695
# std      4.047232e+06    9.126108
# min      9.000000e+00   66.381964
# 25%      2.657000e+03   74.396387
# 50%      1.819100e+04   83.012674
# ...

# %%
cor_mat = df.corr()
cor_mat
# Out:
#                     Year  No Injured  No Affected  No Homeless  Total Deaths  \
# Year            1.000000   -0.058666    -0.066240    -0.271855     -0.061567
# No Injured     -0.058666    1.000000     0.998969     0.196946      0.977196
# No Affected    -0.066240    0.998969     1.000000     0.166846      0.973995
# No Homeless    -0.271855    0.196946     0.166846     1.000000      0.149393
# Total Deaths   -0.061567    0.977196     0.973995     0.149393      1.000000
# Total Affected -0.057138    0.993379     0.999985     0.261487      0.973659
# CPI             0.992192   -0.028677    -0.034421    -0.240816     -0.026295
#
#                 Total Affected       CPI
# Year                 -0.057138  0.992192
# No Injured            0.993379 -0.028677
# No Affected           0.999985 -0.034421
# No Homeless           0.261487 -0.240816
# Total Deaths          0.973659 -0.026295
# Total Affected        1.000000 -0.030275
# CPI                  -0.030275  1.000000

# %%
plt.figure(figsize=(11,8))
sns.heatmap(data = cor_mat, annot = True)
plt.title('Correlation Matrix of Eastern Asia Earthquake Incidents')
plt.show()

# %% [markdown]
# Line Regression

# %%
#changing the size of visualization
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)
#Linear Regression
sns.lmplot(x="CPI", y="Year", data=df)
plt.title("\n Relationship Between CPI and Year", fontweight="bold")
plt.show()

# %%
#changing the size of visualization
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)
#Linear Regression
sns.lmplot(x="Year", y="No Homeless", data=df)
plt.title("\n Relationship Between No Injured and Total Affected", fontweight="bold")
plt.show()
