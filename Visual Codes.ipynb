# %% [markdown]
# <a href="https://colab.research.google.com/github/luzmarie-fer/DataAnalytics/blob/main/Visual%20Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Deaths%20in%20Eastern%20Asia.csv'
df = pd.read_csv(url)
df
# Out:
#   Country  Deaths
# 0  Taiwan     212
# 1   Japan   20034
# 2   Korea       0
# 3   China   92165

# %%
labels= ['Taiwan', 'Japan', 'Korea', 'China']
colors=['#ED553B', '#20639b', '#3CAEA3', '#d45087']

sizes= [8, 235, 113, 235]
plt.figure(figsize = (23,10))
plt.pie(sizes,labels=labels, colors=colors, startangle=90, shadow=True,explode=(0, 0, 0, 0), autopct='%1.2f%%')

plt.axis('equal')
plt.title('Earthquake Deaths Incidents\n', fontdict={'fontname': 'Serif','fontweight':'bold', 'fontsize':20})
plt.legend(labels,loc=1)
plt.show()

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Deaths%20in%20Eastern%20Asia.csv'
df = pd.read_csv(url)
df
# Out:
#   Country  Deaths
# 0  Taiwan     212
# 1   Japan   20034
# 2   Korea       0
# 3   China   92165

# %%
plt.figure(figsize = (17,10))
plt.title("\n Total Deaths in 2 Decades", fontweight="bold", fontsize=20)
plt.bar(x=df['Country'],
 
        height=df['Deaths'],
 
        color='#003f5c')
 
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
url = 'https://raw.githubusercontent.com/luzmarie-fer/DataAnalytics/main/Datasets/Damage%20Chart%20by%20Year.csv'
df = pd.read_csv(url)
df
# Out:
#     Year  TotalDamagesAdjusted
# 0   2002                 37661
# 1   2003                829296
# 2   2004              40346342
# 3   2005                555005
# 4   2006                  9666
# 5   2007              17109549
# 6   2008             321898938
# 7   2009                906992
# 8   2010               1869464
# 9   2011             253390703
# 10  2012               1826969
# 11  2013               9372160
# 12  2014               6457866
# 13  2015                 37556
# 14  2016              23733410
# 15  2017                589209
# 16  2018               5049117
# 17  2019               1379982
# 18  2020                 17799
# 19  2021               9212000
# 20  2022                     0

# %%
#getting all the values stored in the dataframe/csv
Year = df["Year"]
TotalDamagesAdjusted = df["TotalDamagesAdjusted"]

#changing the size of visualization
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)

#Changing the background color of the graph
plt.rcParams['axes.facecolor'] = '#F2F2F2'

#creating the plot
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("\n Total Damages Adjusted in $", fontweight="bold", fontsize=20)
plt.xlabel("Reference Date", fontsize=15)
plt.ylabel("Total Damages", fontsize=15)
plt.plot(Year, TotalDamagesAdjusted, 'o-', c= '#333399', lw=2.4)
plt.grid(color = 'white', linestyle = '--', linewidth = 1.5)
plt.legend(labels=['Damages'])
plt.show()
